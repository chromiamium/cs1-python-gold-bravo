# %% [markdown]
# <a href="https://colab.research.google.com/github/chromiamium/cs1-python-gold-bravo/blob/main/maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
val1 = float(input("Enter the first value: "))
val2 = float(input("Enter the second value: "))
val3 = float(input("Enter the third value: "))


if val1 == val2 == val3:
    print("All values are equal !")
else:
    largest = max(val1, val2, val3)
    print("The largest value among {val1}, {val2}, and {val3} is: {largest}")
